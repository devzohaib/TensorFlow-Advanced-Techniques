# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 948us/sample - loss: 243.6920 - y1_output_loss: 114.4338 - y2_output_loss: 126.9673 - y1_output_root_mean_squared_error: 10.7491 - y2_output_root_mean_squared_error: 11.3203 - val_loss: 30.8261 - val_y1_output_loss: 13.4273 - val_y2_output_loss: 16.3389 - val_y1_output_root_mean_squared_error: 3.7247 - val_y2_output_root_mean_squared_error: 4.1174
# Epoch 2/500
# 614/614 [==============================] - 0s 159us/sample - loss: 30.9873 - y1_output_loss: 12.0987 - y2_output_loss: 18.6985 - y1_output_root_mean_squared_error: 3.4924 - y2_output_root_mean_squared_error: 4.3348 - val_loss: 21.7528 - val_y1_output_loss: 9.5460 - val_y2_output_loss: 11.5477 - val_y1_output_root_mean_squared_error: 3.1370 - val_y2_output_root_mean_squared_error: 3.4514
# Epoch 3/500
# 614/614 [==============================] - 0s 170us/sample - loss: 25.3174 - y1_output_loss: 10.0965 - y2_output_loss: 14.9963 - y1_output_root_mean_squared_error: 3.1912 - y2_output_root_mean_squared_error: 3.8902 - val_loss: 20.0070 - val_y1_output_loss: 8.7868 - val_y2_output_loss: 10.5553 - val_y1_output_root_mean_squared_error: 3.0132 - val_y2_output_root_mean_squared_error: 3.3057
# Epoch 4/500
# 614/614 [==============================] - 0s 145us/sample - loss: 26.0916 - y1_output_loss: 9.9245 - y2_output_loss: 15.9434 - y1_output_root_mean_squared_error: 3.1629 - y2_output_root_mean_squared_error: 4.0109 - val_loss: 34.2136 - val_y1_output_loss: 10.6980 - val_y2_output_loss: 22.6092 - val_y1_output_root_mean_squared_error: 3.3178 - val_y2_output_root_mean_squared_error: 4.8173
# Epoch 5/500
# 614/614 [==============================] - 0s 140us/sample - loss: 25.9420 - y1_output_loss: 9.5328 - y2_output_loss: 16.4516 - y1_output_root_mean_squared_error: 3.0719 - y2_output_root_mean_squared_error: 4.0627 - val_loss: 33.5494 - val_y1_output_loss: 12.2265 - val_y2_output_loss: 20.5127 - val_y1_output_root_mean_squared_error: 3.5545 - val_y2_output_root_mean_squared_error: 4.5732
# Epoch 6/500
# 614/614 [==============================] - 0s 145us/sample - loss: 21.5147 - y1_output_loss: 8.3827 - y2_output_loss: 13.0743 - y1_output_root_mean_squared_error: 2.8922 - y2_output_root_mean_squared_error: 3.6263 - val_loss: 19.6490 - val_y1_output_loss: 8.8287 - val_y2_output_loss: 10.2420 - val_y1_output_root_mean_squared_error: 3.0186 - val_y2_output_root_mean_squared_error: 3.2461
# Epoch 7/500
# 614/614 [==============================] - 0s 151us/sample - loss: 18.9459 - y1_output_loss: 7.6793 - y2_output_loss: 11.2523 - y1_output_root_mean_squared_error: 2.7744 - y2_output_root_mean_squared_error: 3.3539 - val_loss: 21.4583 - val_y1_output_loss: 9.5654 - val_y2_output_loss: 11.1820 - val_y1_output_root_mean_squared_error: 3.1459 - val_y2_output_root_mean_squared_error: 3.4002
# Epoch 8/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.0053 - y1_output_loss: 8.1305 - y2_output_loss: 12.2920 - y1_output_root_mean_squared_error: 2.8206 - y2_output_root_mean_squared_error: 3.4712 - val_loss: 17.7163 - val_y1_output_loss: 7.4547 - val_y2_output_loss: 9.7055 - val_y1_output_root_mean_squared_error: 2.7795 - val_y2_output_root_mean_squared_error: 3.1608
# Epoch 9/500
# 614/614 [==============================] - 0s 144us/sample - loss: 20.7921 - y1_output_loss: 7.7828 - y2_output_loss: 12.8987 - y1_output_root_mean_squared_error: 2.8003 - y2_output_root_mean_squared_error: 3.5987 - val_loss: 19.9506 - val_y1_output_loss: 8.1165 - val_y2_output_loss: 11.2157 - val_y1_output_root_mean_squared_error: 2.8936 - val_y2_output_root_mean_squared_error: 3.4026
# Epoch 10/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.1055 - y1_output_loss: 7.2099 - y2_output_loss: 11.1510 - y1_output_root_mean_squared_error: 2.6706 - y2_output_root_mean_squared_error: 3.3127 - val_loss: 54.9599 - val_y1_output_loss: 14.4356 - val_y2_output_loss: 39.1733 - val_y1_output_root_mean_squared_error: 3.8456 - val_y2_output_root_mean_squared_error: 6.3381
# Epoch 11/500
# 614/614 [==============================] - 0s 137us/sample - loss: 19.8096 - y1_output_loss: 7.3615 - y2_output_loss: 12.4126 - y1_output_root_mean_squared_error: 2.7047 - y2_output_root_mean_squared_error: 3.5347 - val_loss: 19.3160 - val_y1_output_loss: 8.9834 - val_y2_output_loss: 9.6904 - val_y1_output_root_mean_squared_error: 3.0511 - val_y2_output_root_mean_squared_error: 3.1634
# Epoch 12/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.0670 - y1_output_loss: 7.2068 - y2_output_loss: 13.6679 - y1_output_root_mean_squared_error: 2.6959 - y2_output_root_mean_squared_error: 3.7147 - val_loss: 17.4562 - val_y1_output_loss: 6.5450 - val_y2_output_loss: 10.2855 - val_y1_output_root_mean_squared_error: 2.6056 - val_y2_output_root_mean_squared_error: 3.2661
# Epoch 13/500
# 614/614 [==============================] - 0s 140us/sample - loss: 17.0309 - y1_output_loss: 6.5076 - y2_output_loss: 10.7697 - y1_output_root_mean_squared_error: 2.5336 - y2_output_root_mean_squared_error: 3.2576 - val_loss: 18.6858 - val_y1_output_loss: 7.9609 - val_y2_output_loss: 10.1563 - val_y1_output_root_mean_squared_error: 2.8719 - val_y2_output_root_mean_squared_error: 3.2308
# Epoch 14/500
# 614/614 [==============================] - 0s 151us/sample - loss: 15.2545 - y1_output_loss: 5.7983 - y2_output_loss: 9.4590 - y1_output_root_mean_squared_error: 2.4143 - y2_output_root_mean_squared_error: 3.0701 - val_loss: 34.1242 - val_y1_output_loss: 9.6500 - val_y2_output_loss: 23.8169 - val_y1_output_root_mean_squared_error: 3.1491 - val_y2_output_root_mean_squared_error: 4.9201
# Epoch 15/500
# 614/614 [==============================] - 0s 144us/sample - loss: 17.8737 - y1_output_loss: 6.1973 - y2_output_loss: 11.5410 - y1_output_root_mean_squared_error: 2.5008 - y2_output_root_mean_squared_error: 3.4087 - val_loss: 15.0295 - val_y1_output_loss: 6.6928 - val_y2_output_loss: 7.8115 - val_y1_output_root_mean_squared_error: 2.6326 - val_y2_output_root_mean_squared_error: 2.8458
# Epoch 16/500
# 614/614 [==============================] - 0s 146us/sample - loss: 17.6488 - y1_output_loss: 6.0484 - y2_output_loss: 11.5660 - y1_output_root_mean_squared_error: 2.4655 - y2_output_root_mean_squared_error: 3.4015 - val_loss: 15.7701 - val_y1_output_loss: 6.5459 - val_y2_output_loss: 8.6940 - val_y1_output_root_mean_squared_error: 2.6025 - val_y2_output_root_mean_squared_error: 2.9995
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 16.4655 - y1_output_loss: 5.8734 - y2_output_loss: 10.4384 - y1_output_root_mean_squared_error: 2.4345 - y2_output_root_mean_squared_error: 3.2463 - val_loss: 14.5368 - val_y1_output_loss: 6.6540 - val_y2_output_loss: 7.3762 - val_y1_output_root_mean_squared_error: 2.6233 - val_y2_output_root_mean_squared_error: 2.7667
# Epoch 18/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.6562 - y1_output_loss: 5.5766 - y2_output_loss: 8.6279 - y1_output_root_mean_squared_error: 2.3095 - y2_output_root_mean_squared_error: 2.8849 - val_loss: 51.5564 - val_y1_output_loss: 15.3651 - val_y2_output_loss: 35.1325 - val_y1_output_root_mean_squared_error: 3.9557 - val_y2_output_root_mean_squared_error: 5.9924
# Epoch 19/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.2800 - y1_output_loss: 5.3638 - y2_output_loss: 8.9039 - y1_output_root_mean_squared_error: 2.3159 - y2_output_root_mean_squared_error: 2.9861 - val_loss: 22.8278 - val_y1_output_loss: 8.1467 - val_y2_output_loss: 14.0028 - val_y1_output_root_mean_squared_error: 2.8974 - val_y2_output_root_mean_squared_error: 3.7990
# Epoch 20/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.0098 - y1_output_loss: 4.9712 - y2_output_loss: 9.0786 - y1_output_root_mean_squared_error: 2.2365 - y2_output_root_mean_squared_error: 3.0013 - val_loss: 35.1387 - val_y1_output_loss: 9.5402 - val_y2_output_loss: 24.7935 - val_y1_output_root_mean_squared_error: 3.1381 - val_y2_output_root_mean_squared_error: 5.0290
# Epoch 21/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.4708 - y1_output_loss: 4.4967 - y2_output_loss: 7.8958 - y1_output_root_mean_squared_error: 2.1265 - y2_output_root_mean_squared_error: 2.8194 - val_loss: 15.4631 - val_y1_output_loss: 6.6229 - val_y2_output_loss: 8.3740 - val_y1_output_root_mean_squared_error: 2.6104 - val_y2_output_root_mean_squared_error: 2.9409
# Epoch 22/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.2650 - y1_output_loss: 4.7500 - y2_output_loss: 9.4771 - y1_output_root_mean_squared_error: 2.1877 - y2_output_root_mean_squared_error: 3.0788 - val_loss: 18.4731 - val_y1_output_loss: 7.1996 - val_y2_output_loss: 10.8079 - val_y1_output_root_mean_squared_error: 2.7173 - val_y2_output_root_mean_squared_error: 3.3301
# Epoch 23/500
# 614/614 [==============================] - 0s 149us/sample - loss: 11.7956 - y1_output_loss: 4.4379 - y2_output_loss: 7.3782 - y1_output_root_mean_squared_error: 2.0961 - y2_output_root_mean_squared_error: 2.7207 - val_loss: 18.0575 - val_y1_output_loss: 8.0180 - val_y2_output_loss: 9.6298 - val_y1_output_root_mean_squared_error: 2.8699 - val_y2_output_root_mean_squared_error: 3.1339
# Epoch 24/500
# 614/614 [==============================] - 0s 150us/sample - loss: 11.6461 - y1_output_loss: 4.2704 - y2_output_loss: 7.3675 - y1_output_root_mean_squared_error: 2.0643 - y2_output_root_mean_squared_error: 2.7175 - val_loss: 12.0848 - val_y1_output_loss: 5.4879 - val_y2_output_loss: 6.1900 - val_y1_output_root_mean_squared_error: 2.3839 - val_y2_output_root_mean_squared_error: 2.5302
# Epoch 25/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.7815 - y1_output_loss: 4.8957 - y2_output_loss: 9.9763 - y1_output_root_mean_squared_error: 2.2110 - y2_output_root_mean_squared_error: 3.1453 - val_loss: 24.7851 - val_y1_output_loss: 7.5611 - val_y2_output_loss: 16.6037 - val_y1_output_root_mean_squared_error: 2.7969 - val_y2_output_root_mean_squared_error: 4.1186
# Epoch 26/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.5250 - y1_output_loss: 4.0338 - y2_output_loss: 7.6674 - y1_output_root_mean_squared_error: 1.9967 - y2_output_root_mean_squared_error: 2.7456 - val_loss: 12.5017 - val_y1_output_loss: 5.2100 - val_y2_output_loss: 6.8511 - val_y1_output_root_mean_squared_error: 2.3250 - val_y2_output_root_mean_squared_error: 2.6638
# Epoch 27/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.6001 - y1_output_loss: 3.9648 - y2_output_loss: 6.5690 - y1_output_root_mean_squared_error: 1.9974 - y2_output_root_mean_squared_error: 2.5711 - val_loss: 11.7686 - val_y1_output_loss: 5.1991 - val_y2_output_loss: 6.2606 - val_y1_output_root_mean_squared_error: 2.3148 - val_y2_output_root_mean_squared_error: 2.5319
# Epoch 28/500
# 614/614 [==============================] - 0s 151us/sample - loss: 9.9476 - y1_output_loss: 3.6721 - y2_output_loss: 6.3908 - y1_output_root_mean_squared_error: 1.9003 - y2_output_root_mean_squared_error: 2.5172 - val_loss: 15.0929 - val_y1_output_loss: 6.2678 - val_y2_output_loss: 8.3824 - val_y1_output_root_mean_squared_error: 2.5390 - val_y2_output_root_mean_squared_error: 2.9404
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.6478 - y1_output_loss: 3.7244 - y2_output_loss: 5.9792 - y1_output_root_mean_squared_error: 1.9216 - y2_output_root_mean_squared_error: 2.4403 - val_loss: 14.5204 - val_y1_output_loss: 4.6887 - val_y2_output_loss: 9.3591 - val_y1_output_root_mean_squared_error: 2.2038 - val_y2_output_root_mean_squared_error: 3.1087
# Epoch 30/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.4910 - y1_output_loss: 3.0305 - y2_output_loss: 5.4811 - y1_output_root_mean_squared_error: 1.7439 - y2_output_root_mean_squared_error: 2.3345 - val_loss: 26.6574 - val_y1_output_loss: 7.1661 - val_y2_output_loss: 19.0562 - val_y1_output_root_mean_squared_error: 2.7110 - val_y2_output_root_mean_squared_error: 4.3941
# Epoch 31/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.4066 - y1_output_loss: 3.7032 - y2_output_loss: 7.7994 - y1_output_root_mean_squared_error: 1.9181 - y2_output_root_mean_squared_error: 2.7798 - val_loss: 18.4809 - val_y1_output_loss: 5.2336 - val_y2_output_loss: 12.6915 - val_y1_output_root_mean_squared_error: 2.3267 - val_y2_output_root_mean_squared_error: 3.6148
# Epoch 32/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.2814 - y1_output_loss: 3.6243 - y2_output_loss: 7.9027 - y1_output_root_mean_squared_error: 1.8683 - y2_output_root_mean_squared_error: 2.7912 - val_loss: 47.6078 - val_y1_output_loss: 12.3751 - val_y2_output_loss: 34.0490 - val_y1_output_root_mean_squared_error: 3.5648 - val_y2_output_root_mean_squared_error: 5.9076
# Epoch 33/500
# 614/614 [==============================] - 0s 157us/sample - loss: 12.9278 - y1_output_loss: 4.0957 - y2_output_loss: 8.7737 - y1_output_root_mean_squared_error: 2.0286 - y2_output_root_mean_squared_error: 2.9686 - val_loss: 9.4700 - val_y1_output_loss: 3.3487 - val_y2_output_loss: 5.8146 - val_y1_output_root_mean_squared_error: 1.8629 - val_y2_output_root_mean_squared_error: 2.4494
# Epoch 34/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.1913 - y1_output_loss: 2.7465 - y2_output_loss: 5.4028 - y1_output_root_mean_squared_error: 1.6621 - y2_output_root_mean_squared_error: 2.3299 - val_loss: 11.1519 - val_y1_output_loss: 4.8077 - val_y2_output_loss: 6.1735 - val_y1_output_root_mean_squared_error: 2.2121 - val_y2_output_root_mean_squared_error: 2.5017
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.2859 - y1_output_loss: 2.8192 - y2_output_loss: 5.4306 - y1_output_root_mean_squared_error: 1.6843 - y2_output_root_mean_squared_error: 2.3343 - val_loss: 9.2671 - val_y1_output_loss: 3.3974 - val_y2_output_loss: 5.5454 - val_y1_output_root_mean_squared_error: 1.8777 - val_y2_output_root_mean_squared_error: 2.3961
# Epoch 36/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.4865 - y1_output_loss: 2.7919 - y2_output_loss: 5.6801 - y1_output_root_mean_squared_error: 1.6771 - y2_output_root_mean_squared_error: 2.3820 - val_loss: 12.8946 - val_y1_output_loss: 4.0577 - val_y2_output_loss: 8.6682 - val_y1_output_root_mean_squared_error: 2.0375 - val_y2_output_root_mean_squared_error: 2.9569
# Epoch 37/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.1992 - y1_output_loss: 2.7256 - y2_output_loss: 5.4328 - y1_output_root_mean_squared_error: 1.6579 - y2_output_root_mean_squared_error: 2.3346 - val_loss: 7.7450 - val_y1_output_loss: 2.9579 - val_y2_output_loss: 4.6068 - val_y1_output_root_mean_squared_error: 1.7475 - val_y2_output_root_mean_squared_error: 2.1660
# Epoch 38/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.9863 - y1_output_loss: 2.5328 - y2_output_loss: 5.3866 - y1_output_root_mean_squared_error: 1.5969 - y2_output_root_mean_squared_error: 2.3316 - val_loss: 7.3640 - val_y1_output_loss: 2.8760 - val_y2_output_loss: 4.2260 - val_y1_output_root_mean_squared_error: 1.7285 - val_y2_output_root_mean_squared_error: 2.0920
# Epoch 39/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.5360 - y1_output_loss: 2.8511 - y2_output_loss: 5.6334 - y1_output_root_mean_squared_error: 1.6942 - y2_output_root_mean_squared_error: 2.3803 - val_loss: 14.0380 - val_y1_output_loss: 3.8212 - val_y2_output_loss: 10.0086 - val_y1_output_root_mean_squared_error: 1.9779 - val_y2_output_root_mean_squared_error: 3.1821
# Epoch 40/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.8121 - y1_output_loss: 2.7859 - y2_output_loss: 6.0196 - y1_output_root_mean_squared_error: 1.6753 - y2_output_root_mean_squared_error: 2.4506 - val_loss: 9.7790 - val_y1_output_loss: 3.2452 - val_y2_output_loss: 6.3646 - val_y1_output_root_mean_squared_error: 1.8157 - val_y2_output_root_mean_squared_error: 2.5460
# Epoch 41/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.1676 - y1_output_loss: 2.9826 - y2_output_loss: 7.0997 - y1_output_root_mean_squared_error: 1.7331 - y2_output_root_mean_squared_error: 2.6766 - val_loss: 6.8095 - val_y1_output_loss: 2.7590 - val_y2_output_loss: 3.8227 - val_y1_output_root_mean_squared_error: 1.6914 - val_y2_output_root_mean_squared_error: 1.9871
# Epoch 42/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.7679 - y1_output_loss: 2.5086 - y2_output_loss: 5.2586 - y1_output_root_mean_squared_error: 1.5840 - y2_output_root_mean_squared_error: 2.2932 - val_loss: 8.6771 - val_y1_output_loss: 3.3280 - val_y2_output_loss: 5.0704 - val_y1_output_root_mean_squared_error: 1.8536 - val_y2_output_root_mean_squared_error: 2.2894
# Epoch 43/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.4159 - y1_output_loss: 2.2651 - y2_output_loss: 5.1636 - y1_output_root_mean_squared_error: 1.5032 - y2_output_root_mean_squared_error: 2.2707 - val_loss: 8.7540 - val_y1_output_loss: 3.8725 - val_y2_output_loss: 4.7750 - val_y1_output_root_mean_squared_error: 1.9819 - val_y2_output_root_mean_squared_error: 2.1968
# Epoch 44/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.3563 - y1_output_loss: 1.9945 - y2_output_loss: 4.4298 - y1_output_root_mean_squared_error: 1.3940 - y2_output_root_mean_squared_error: 2.1008 - val_loss: 30.0037 - val_y1_output_loss: 8.4326 - val_y2_output_loss: 20.7640 - val_y1_output_root_mean_squared_error: 2.9448 - val_y2_output_root_mean_squared_error: 4.6186
# Epoch 45/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.2675 - y1_output_loss: 2.2720 - y2_output_loss: 4.9894 - y1_output_root_mean_squared_error: 1.5078 - y2_output_root_mean_squared_error: 2.2347 - val_loss: 8.9033 - val_y1_output_loss: 2.9012 - val_y2_output_loss: 5.8187 - val_y1_output_root_mean_squared_error: 1.7276 - val_y2_output_root_mean_squared_error: 2.4329
# Epoch 46/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.6294 - y1_output_loss: 2.1708 - y2_output_loss: 5.4825 - y1_output_root_mean_squared_error: 1.4693 - y2_output_root_mean_squared_error: 2.3389 - val_loss: 6.8236 - val_y1_output_loss: 2.8417 - val_y2_output_loss: 3.8080 - val_y1_output_root_mean_squared_error: 1.7105 - val_y2_output_root_mean_squared_error: 1.9743
# Epoch 47/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.2173 - y1_output_loss: 2.5457 - y2_output_loss: 5.6654 - y1_output_root_mean_squared_error: 1.5929 - y2_output_root_mean_squared_error: 2.3833 - val_loss: 7.4896 - val_y1_output_loss: 3.2532 - val_y2_output_loss: 4.1287 - val_y1_output_root_mean_squared_error: 1.8195 - val_y2_output_root_mean_squared_error: 2.0443
# Epoch 48/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.3044 - y1_output_loss: 2.5209 - y2_output_loss: 5.8500 - y1_output_root_mean_squared_error: 1.5728 - y2_output_root_mean_squared_error: 2.4147 - val_loss: 11.7964 - val_y1_output_loss: 4.3089 - val_y2_output_loss: 7.0811 - val_y1_output_root_mean_squared_error: 2.1123 - val_y2_output_root_mean_squared_error: 2.7083
# Epoch 49/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.5979 - y1_output_loss: 2.3358 - y2_output_loss: 5.1929 - y1_output_root_mean_squared_error: 1.5349 - y2_output_root_mean_squared_error: 2.2895 - val_loss: 5.7202 - val_y1_output_loss: 2.1387 - val_y2_output_loss: 3.4426 - val_y1_output_root_mean_squared_error: 1.4823 - val_y2_output_root_mean_squared_error: 1.8770
# Epoch 50/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.1112 - y1_output_loss: 1.9871 - y2_output_loss: 4.1507 - y1_output_root_mean_squared_error: 1.3925 - y2_output_root_mean_squared_error: 2.0425 - val_loss: 9.5930 - val_y1_output_loss: 2.6585 - val_y2_output_loss: 6.5986 - val_y1_output_root_mean_squared_error: 1.6616 - val_y2_output_root_mean_squared_error: 2.6138
# Epoch 51/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.1100 - y1_output_loss: 2.0465 - y2_output_loss: 5.1430 - y1_output_root_mean_squared_error: 1.4216 - y2_output_root_mean_squared_error: 2.2559 - val_loss: 22.4851 - val_y1_output_loss: 6.2794 - val_y2_output_loss: 16.1970 - val_y1_output_root_mean_squared_error: 2.5073 - val_y2_output_root_mean_squared_error: 4.0248
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.3275 - y1_output_loss: 2.8282 - y2_output_loss: 7.5627 - y1_output_root_mean_squared_error: 1.6755 - y2_output_root_mean_squared_error: 2.7423 - val_loss: 7.3949 - val_y1_output_loss: 2.4831 - val_y2_output_loss: 4.6741 - val_y1_output_root_mean_squared_error: 1.6005 - val_y2_output_root_mean_squared_error: 2.1985
# Epoch 53/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.6469 - y1_output_loss: 1.9614 - y2_output_loss: 4.6867 - y1_output_root_mean_squared_error: 1.4038 - y2_output_root_mean_squared_error: 2.1625 - val_loss: 7.2310 - val_y1_output_loss: 2.8315 - val_y2_output_loss: 4.2480 - val_y1_output_root_mean_squared_error: 1.7001 - val_y2_output_root_mean_squared_error: 2.0834
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.1654 - y1_output_loss: 2.9913 - y2_output_loss: 6.2547 - y1_output_root_mean_squared_error: 1.7356 - y2_output_root_mean_squared_error: 2.4805 - val_loss: 16.6953 - val_y1_output_loss: 3.8092 - val_y2_output_loss: 12.5008 - val_y1_output_root_mean_squared_error: 1.9673 - val_y2_output_root_mean_squared_error: 3.5812
# Epoch 55/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.4669 - y1_output_loss: 1.6984 - y2_output_loss: 3.8083 - y1_output_root_mean_squared_error: 1.3023 - y2_output_root_mean_squared_error: 1.9419 - val_loss: 6.0324 - val_y1_output_loss: 2.4874 - val_y2_output_loss: 3.4043 - val_y1_output_root_mean_squared_error: 1.5962 - val_y2_output_root_mean_squared_error: 1.8667
# Epoch 56/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7117 - y1_output_loss: 1.7534 - y2_output_loss: 3.9536 - y1_output_root_mean_squared_error: 1.3269 - y2_output_root_mean_squared_error: 1.9877 - val_loss: 7.0565 - val_y1_output_loss: 2.6884 - val_y2_output_loss: 4.3013 - val_y1_output_root_mean_squared_error: 1.6492 - val_y2_output_root_mean_squared_error: 2.0825
# Epoch 57/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.6092 - y1_output_loss: 1.9775 - y2_output_loss: 4.7375 - y1_output_root_mean_squared_error: 1.3976 - y2_output_root_mean_squared_error: 2.1578 - val_loss: 5.9474 - val_y1_output_loss: 2.0446 - val_y2_output_loss: 3.7451 - val_y1_output_root_mean_squared_error: 1.4522 - val_y2_output_root_mean_squared_error: 1.9592
# Epoch 58/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.9045 - y1_output_loss: 2.5001 - y2_output_loss: 6.3744 - y1_output_root_mean_squared_error: 1.5876 - y2_output_root_mean_squared_error: 2.5267 - val_loss: 7.5555 - val_y1_output_loss: 1.9709 - val_y2_output_loss: 5.4383 - val_y1_output_root_mean_squared_error: 1.4267 - val_y2_output_root_mean_squared_error: 2.3495
# Epoch 59/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.5796 - y1_output_loss: 1.9392 - y2_output_loss: 4.6738 - y1_output_root_mean_squared_error: 1.3925 - y2_output_root_mean_squared_error: 2.1542 - val_loss: 11.8003 - val_y1_output_loss: 3.7043 - val_y2_output_loss: 7.7074 - val_y1_output_root_mean_squared_error: 1.9552 - val_y2_output_root_mean_squared_error: 2.8245
# Epoch 60/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.5512 - y1_output_loss: 2.9419 - y2_output_loss: 7.6413 - y1_output_root_mean_squared_error: 1.7210 - y2_output_root_mean_squared_error: 2.7549 - val_loss: 14.7826 - val_y1_output_loss: 2.9896 - val_y2_output_loss: 11.6412 - val_y1_output_root_mean_squared_error: 1.7475 - val_y2_output_root_mean_squared_error: 3.4247
# Epoch 61/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.7616 - y1_output_loss: 1.6651 - y2_output_loss: 4.0812 - y1_output_root_mean_squared_error: 1.2926 - y2_output_root_mean_squared_error: 2.0226 - val_loss: 5.7195 - val_y1_output_loss: 1.7448 - val_y2_output_loss: 3.9039 - val_y1_output_root_mean_squared_error: 1.3363 - val_y2_output_root_mean_squared_error: 1.9834
# Epoch 62/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.5210 - y1_output_loss: 1.5150 - y2_output_loss: 3.9969 - y1_output_root_mean_squared_error: 1.2238 - y2_output_root_mean_squared_error: 2.0058 - val_loss: 5.9810 - val_y1_output_loss: 2.3055 - val_y2_output_loss: 3.5854 - val_y1_output_root_mean_squared_error: 1.5330 - val_y2_output_root_mean_squared_error: 1.9055
# Epoch 63/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.1141 - y1_output_loss: 1.6802 - y2_output_loss: 4.4493 - y1_output_root_mean_squared_error: 1.2905 - y2_output_root_mean_squared_error: 2.1092 - val_loss: 7.3245 - val_y1_output_loss: 3.3973 - val_y2_output_loss: 3.9321 - val_y1_output_root_mean_squared_error: 1.8450 - val_y2_output_root_mean_squared_error: 1.9801
# Epoch 64/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.2228 - y1_output_loss: 1.9034 - y2_output_loss: 4.2651 - y1_output_root_mean_squared_error: 1.3855 - y2_output_root_mean_squared_error: 2.0744 - val_loss: 4.8642 - val_y1_output_loss: 1.7468 - val_y2_output_loss: 2.9904 - val_y1_output_root_mean_squared_error: 1.3413 - val_y2_output_root_mean_squared_error: 1.7508
# Epoch 65/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.6924 - y1_output_loss: 1.7359 - y2_output_loss: 4.0061 - y1_output_root_mean_squared_error: 1.3152 - y2_output_root_mean_squared_error: 1.9906 - val_loss: 15.7456 - val_y1_output_loss: 4.7628 - val_y2_output_loss: 10.9049 - val_y1_output_root_mean_squared_error: 2.1916 - val_y2_output_root_mean_squared_error: 3.3079
# Epoch 66/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.0521 - y1_output_loss: 2.3632 - y2_output_loss: 5.6552 - y1_output_root_mean_squared_error: 1.5399 - y2_output_root_mean_squared_error: 2.3835 - val_loss: 5.0952 - val_y1_output_loss: 1.7893 - val_y2_output_loss: 3.1284 - val_y1_output_root_mean_squared_error: 1.3620 - val_y2_output_root_mean_squared_error: 1.8001
# Epoch 67/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.5000 - y1_output_loss: 1.5476 - y2_output_loss: 3.9565 - y1_output_root_mean_squared_error: 1.2345 - y2_output_root_mean_squared_error: 1.9940 - val_loss: 5.3079 - val_y1_output_loss: 2.3042 - val_y2_output_loss: 2.9902 - val_y1_output_root_mean_squared_error: 1.5168 - val_y2_output_root_mean_squared_error: 1.7342
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5510 - y1_output_loss: 1.2178 - y2_output_loss: 3.3037 - y1_output_root_mean_squared_error: 1.1059 - y2_output_root_mean_squared_error: 1.8242 - val_loss: 4.4026 - val_y1_output_loss: 1.4555 - val_y2_output_loss: 2.9112 - val_y1_output_root_mean_squared_error: 1.2128 - val_y2_output_root_mean_squared_error: 1.7122
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.7165 - y1_output_loss: 2.0473 - y2_output_loss: 5.6641 - y1_output_root_mean_squared_error: 1.4355 - y2_output_root_mean_squared_error: 2.3782 - val_loss: 10.7612 - val_y1_output_loss: 1.7713 - val_y2_output_loss: 8.8690 - val_y1_output_root_mean_squared_error: 1.3480 - val_y2_output_root_mean_squared_error: 2.9907
# Epoch 70/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.1971 - y1_output_loss: 1.3138 - y2_output_loss: 3.8746 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.9763 - val_loss: 3.9048 - val_y1_output_loss: 1.2737 - val_y2_output_loss: 2.5174 - val_y1_output_root_mean_squared_error: 1.1456 - val_y2_output_root_mean_squared_error: 1.6101
# Epoch 71/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.1355 - y1_output_loss: 1.7557 - y2_output_loss: 4.3795 - y1_output_root_mean_squared_error: 1.3244 - y2_output_root_mean_squared_error: 2.0932 - val_loss: 10.3807 - val_y1_output_loss: 3.0996 - val_y2_output_loss: 7.2333 - val_y1_output_root_mean_squared_error: 1.7737 - val_y2_output_root_mean_squared_error: 2.6897
# Epoch 72/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.0724 - y1_output_loss: 1.6608 - y2_output_loss: 4.4208 - y1_output_root_mean_squared_error: 1.2940 - y2_output_root_mean_squared_error: 2.0971 - val_loss: 4.8627 - val_y1_output_loss: 1.6711 - val_y2_output_loss: 3.0464 - val_y1_output_root_mean_squared_error: 1.3153 - val_y2_output_root_mean_squared_error: 1.7699
# Epoch 73/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.6909 - y1_output_loss: 1.1399 - y2_output_loss: 3.5297 - y1_output_root_mean_squared_error: 1.0666 - y2_output_root_mean_squared_error: 1.8850 - val_loss: 7.6863 - val_y1_output_loss: 2.5541 - val_y2_output_loss: 4.9615 - val_y1_output_root_mean_squared_error: 1.6226 - val_y2_output_root_mean_squared_error: 2.2480
# Epoch 74/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.1509 - y1_output_loss: 1.4007 - y2_output_loss: 3.7659 - y1_output_root_mean_squared_error: 1.1831 - y2_output_root_mean_squared_error: 1.9368 - val_loss: 4.8757 - val_y1_output_loss: 1.3845 - val_y2_output_loss: 3.3188 - val_y1_output_root_mean_squared_error: 1.1989 - val_y2_output_root_mean_squared_error: 1.8543
# Epoch 75/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.4284 - y1_output_loss: 2.6996 - y2_output_loss: 6.7363 - y1_output_root_mean_squared_error: 1.6441 - y2_output_root_mean_squared_error: 2.5933 - val_loss: 10.6061 - val_y1_output_loss: 3.6170 - val_y2_output_loss: 6.7894 - val_y1_output_root_mean_squared_error: 1.9284 - val_y2_output_root_mean_squared_error: 2.6244
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.1361 - y1_output_loss: 2.4699 - y2_output_loss: 5.6090 - y1_output_root_mean_squared_error: 1.5780 - y2_output_root_mean_squared_error: 2.3762 - val_loss: 4.2615 - val_y1_output_loss: 1.1192 - val_y2_output_loss: 3.0942 - val_y1_output_root_mean_squared_error: 1.0679 - val_y2_output_root_mean_squared_error: 1.7666
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5708 - y1_output_loss: 0.8802 - y2_output_loss: 2.6875 - y1_output_root_mean_squared_error: 0.9417 - y2_output_root_mean_squared_error: 1.6383 - val_loss: 3.7600 - val_y1_output_loss: 1.1085 - val_y2_output_loss: 2.6022 - val_y1_output_root_mean_squared_error: 1.0650 - val_y2_output_root_mean_squared_error: 1.6204
# Epoch 78/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2479 - y1_output_loss: 1.1309 - y2_output_loss: 3.0847 - y1_output_root_mean_squared_error: 1.0675 - y2_output_root_mean_squared_error: 1.7630 - val_loss: 3.7156 - val_y1_output_loss: 1.3276 - val_y2_output_loss: 2.3494 - val_y1_output_root_mean_squared_error: 1.1572 - val_y2_output_root_mean_squared_error: 1.5416
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1824 - y1_output_loss: 1.5280 - y2_output_loss: 4.6017 - y1_output_root_mean_squared_error: 1.2396 - y2_output_root_mean_squared_error: 2.1554 - val_loss: 3.3947 - val_y1_output_loss: 0.8823 - val_y2_output_loss: 2.3979 - val_y1_output_root_mean_squared_error: 0.9541 - val_y2_output_root_mean_squared_error: 1.5762
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.4319 - y1_output_loss: 0.8271 - y2_output_loss: 2.5863 - y1_output_root_mean_squared_error: 0.9111 - y2_output_root_mean_squared_error: 1.6130 - val_loss: 3.0708 - val_y1_output_loss: 0.9399 - val_y2_output_loss: 2.0350 - val_y1_output_root_mean_squared_error: 0.9857 - val_y2_output_root_mean_squared_error: 1.4488
# Epoch 81/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.9800 - y1_output_loss: 0.8896 - y2_output_loss: 3.0919 - y1_output_root_mean_squared_error: 0.9461 - y2_output_root_mean_squared_error: 1.7564 - val_loss: 5.3798 - val_y1_output_loss: 1.6368 - val_y2_output_loss: 3.6104 - val_y1_output_root_mean_squared_error: 1.2923 - val_y2_output_root_mean_squared_error: 1.9261
# Epoch 82/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0191 - y1_output_loss: 0.7281 - y2_output_loss: 2.2893 - y1_output_root_mean_squared_error: 0.8540 - y2_output_root_mean_squared_error: 1.5132 - val_loss: 3.0987 - val_y1_output_loss: 0.8118 - val_y2_output_loss: 2.1867 - val_y1_output_root_mean_squared_error: 0.9160 - val_y2_output_root_mean_squared_error: 1.5032
# Epoch 83/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6200 - y1_output_loss: 0.9435 - y2_output_loss: 2.6471 - y1_output_root_mean_squared_error: 0.9751 - y2_output_root_mean_squared_error: 1.6337 - val_loss: 4.8622 - val_y1_output_loss: 1.1436 - val_y2_output_loss: 3.5437 - val_y1_output_root_mean_squared_error: 1.0876 - val_y2_output_root_mean_squared_error: 1.9182
# Epoch 84/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9810 - y1_output_loss: 1.5116 - y2_output_loss: 3.9771 - y1_output_root_mean_squared_error: 1.1712 - y2_output_root_mean_squared_error: 1.8998 - val_loss: 42.5718 - val_y1_output_loss: 9.8584 - val_y2_output_loss: 32.1229 - val_y1_output_root_mean_squared_error: 3.1577 - val_y2_output_root_mean_squared_error: 5.7097
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.3944 - y1_output_loss: 1.1319 - y2_output_loss: 3.2348 - y1_output_root_mean_squared_error: 1.0630 - y2_output_root_mean_squared_error: 1.8068 - val_loss: 3.0885 - val_y1_output_loss: 0.7110 - val_y2_output_loss: 2.2792 - val_y1_output_root_mean_squared_error: 0.8557 - val_y2_output_root_mean_squared_error: 1.5350
# Epoch 86/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3860 - y1_output_loss: 1.1978 - y2_output_loss: 3.1608 - y1_output_root_mean_squared_error: 1.0970 - y2_output_root_mean_squared_error: 1.7840 - val_loss: 2.7158 - val_y1_output_loss: 0.8478 - val_y2_output_loss: 1.7840 - val_y1_output_root_mean_squared_error: 0.9336 - val_y2_output_root_mean_squared_error: 1.3580
# Epoch 87/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.8120 - y1_output_loss: 0.8957 - y2_output_loss: 2.9051 - y1_output_root_mean_squared_error: 0.9487 - y2_output_root_mean_squared_error: 1.7064 - val_loss: 3.6375 - val_y1_output_loss: 0.8062 - val_y2_output_loss: 2.7228 - val_y1_output_root_mean_squared_error: 0.9103 - val_y2_output_root_mean_squared_error: 1.6760
# Epoch 88/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7732 - y1_output_loss: 0.6311 - y2_output_loss: 2.1724 - y1_output_root_mean_squared_error: 0.7963 - y2_output_root_mean_squared_error: 1.4626 - val_loss: 2.8861 - val_y1_output_loss: 0.9988 - val_y2_output_loss: 1.8665 - val_y1_output_root_mean_squared_error: 1.0027 - val_y2_output_root_mean_squared_error: 1.3714
# Epoch 89/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.2190 - y1_output_loss: 0.7788 - y2_output_loss: 2.4177 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.5603 - val_loss: 2.8108 - val_y1_output_loss: 0.9906 - val_y2_output_loss: 1.7229 - val_y1_output_root_mean_squared_error: 1.0131 - val_y2_output_root_mean_squared_error: 1.3358
# Epoch 90/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9070 - y1_output_loss: 0.7684 - y2_output_loss: 2.1402 - y1_output_root_mean_squared_error: 0.8796 - y2_output_root_mean_squared_error: 1.4606 - val_loss: 4.2794 - val_y1_output_loss: 1.2367 - val_y2_output_loss: 3.0405 - val_y1_output_root_mean_squared_error: 1.1149 - val_y2_output_root_mean_squared_error: 1.7425
# Epoch 91/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.2790 - y1_output_loss: 2.6658 - y2_output_loss: 6.5640 - y1_output_root_mean_squared_error: 1.6370 - y2_output_root_mean_squared_error: 2.5689 - val_loss: 3.5458 - val_y1_output_loss: 1.1128 - val_y2_output_loss: 2.3188 - val_y1_output_root_mean_squared_error: 1.0697 - val_y2_output_root_mean_squared_error: 1.5497
# Epoch 92/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9515 - y1_output_loss: 0.6188 - y2_output_loss: 2.4497 - y1_output_root_mean_squared_error: 0.7900 - y2_output_root_mean_squared_error: 1.5256 - val_loss: 11.3487 - val_y1_output_loss: 1.5754 - val_y2_output_loss: 9.4709 - val_y1_output_root_mean_squared_error: 1.2734 - val_y2_output_root_mean_squared_error: 3.1189
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4845 - y1_output_loss: 0.8524 - y2_output_loss: 2.6267 - y1_output_root_mean_squared_error: 0.9163 - y2_output_root_mean_squared_error: 1.6263 - val_loss: 2.5845 - val_y1_output_loss: 0.8160 - val_y2_output_loss: 1.6844 - val_y1_output_root_mean_squared_error: 0.9149 - val_y2_output_root_mean_squared_error: 1.3219
# Epoch 94/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.4232 - y1_output_loss: 0.7112 - y2_output_loss: 2.6965 - y1_output_root_mean_squared_error: 0.8416 - y2_output_root_mean_squared_error: 1.6477 - val_loss: 2.7511 - val_y1_output_loss: 0.7032 - val_y2_output_loss: 1.9492 - val_y1_output_root_mean_squared_error: 0.8532 - val_y2_output_root_mean_squared_error: 1.4224
# Epoch 95/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.2572 - y1_output_loss: 0.8027 - y2_output_loss: 2.4541 - y1_output_root_mean_squared_error: 0.8998 - y2_output_root_mean_squared_error: 1.5645 - val_loss: 4.8995 - val_y1_output_loss: 1.0859 - val_y2_output_loss: 3.6593 - val_y1_output_root_mean_squared_error: 1.0568 - val_y2_output_root_mean_squared_error: 1.9449
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5108 - y1_output_loss: 0.6437 - y2_output_loss: 1.8678 - y1_output_root_mean_squared_error: 0.7963 - y2_output_root_mean_squared_error: 1.3699 - val_loss: 2.1146 - val_y1_output_loss: 0.6547 - val_y2_output_loss: 1.3963 - val_y1_output_root_mean_squared_error: 0.8219 - val_y2_output_root_mean_squared_error: 1.1997
# Epoch 97/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.0722 - y1_output_loss: 0.6190 - y2_output_loss: 2.5348 - y1_output_root_mean_squared_error: 0.7902 - y2_output_root_mean_squared_error: 1.5646 - val_loss: 12.2877 - val_y1_output_loss: 1.2955 - val_y2_output_loss: 10.7915 - val_y1_output_root_mean_squared_error: 1.1560 - val_y2_output_root_mean_squared_error: 3.3093
# Epoch 98/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6084 - y1_output_loss: 1.1645 - y2_output_loss: 3.4023 - y1_output_root_mean_squared_error: 1.0842 - y2_output_root_mean_squared_error: 1.8528 - val_loss: 2.2461 - val_y1_output_loss: 0.5837 - val_y2_output_loss: 1.6322 - val_y1_output_root_mean_squared_error: 0.7699 - val_y2_output_root_mean_squared_error: 1.2859
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8271 - y1_output_loss: 0.9338 - y2_output_loss: 2.8842 - y1_output_root_mean_squared_error: 0.9684 - y2_output_root_mean_squared_error: 1.6998 - val_loss: 4.1368 - val_y1_output_loss: 1.4421 - val_y2_output_loss: 2.6603 - val_y1_output_root_mean_squared_error: 1.2036 - val_y2_output_root_mean_squared_error: 1.6396
# Epoch 100/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.7975 - y1_output_loss: 0.6859 - y2_output_loss: 2.0896 - y1_output_root_mean_squared_error: 0.8319 - y2_output_root_mean_squared_error: 1.4511 - val_loss: 2.0877 - val_y1_output_loss: 0.5518 - val_y2_output_loss: 1.4906 - val_y1_output_root_mean_squared_error: 0.7536 - val_y2_output_root_mean_squared_error: 1.2328
# Epoch 101/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.9240 - y1_output_loss: 0.6601 - y2_output_loss: 2.2380 - y1_output_root_mean_squared_error: 0.8161 - y2_output_root_mean_squared_error: 1.5026 - val_loss: 2.3387 - val_y1_output_loss: 0.5574 - val_y2_output_loss: 1.7631 - val_y1_output_root_mean_squared_error: 0.7532 - val_y2_output_root_mean_squared_error: 1.3310
# Epoch 102/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.3844 - y1_output_loss: 0.5434 - y2_output_loss: 1.8246 - y1_output_root_mean_squared_error: 0.7396 - y2_output_root_mean_squared_error: 1.3555 - val_loss: 1.9212 - val_y1_output_loss: 0.5551 - val_y2_output_loss: 1.3025 - val_y1_output_root_mean_squared_error: 0.7578 - val_y2_output_root_mean_squared_error: 1.1606
# Epoch 103/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.9403 - y1_output_loss: 0.5705 - y2_output_loss: 2.3882 - y1_output_root_mean_squared_error: 0.7512 - y2_output_root_mean_squared_error: 1.5414 - val_loss: 6.3665 - val_y1_output_loss: 2.0082 - val_y2_output_loss: 4.3166 - val_y1_output_root_mean_squared_error: 1.4272 - val_y2_output_root_mean_squared_error: 2.0807
# Epoch 104/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.9137 - y1_output_loss: 0.7995 - y2_output_loss: 2.0921 - y1_output_root_mean_squared_error: 0.8960 - y2_output_root_mean_squared_error: 1.4529 - val_loss: 2.4676 - val_y1_output_loss: 0.8612 - val_y2_output_loss: 1.5370 - val_y1_output_root_mean_squared_error: 0.9362 - val_y2_output_root_mean_squared_error: 1.2614
# Epoch 105/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.9200 - y1_output_loss: 0.6522 - y2_output_loss: 2.2758 - y1_output_root_mean_squared_error: 0.8010 - y2_output_root_mean_squared_error: 1.5095 - val_loss: 3.7867 - val_y1_output_loss: 1.6749 - val_y2_output_loss: 2.0230 - val_y1_output_root_mean_squared_error: 1.3091 - val_y2_output_root_mean_squared_error: 1.4398
# Epoch 106/500
# 614/614 [==============================] - 0s 186us/sample - loss: 2.3844 - y1_output_loss: 0.6117 - y2_output_loss: 1.9211 - y1_output_root_mean_squared_error: 0.7690 - y2_output_root_mean_squared_error: 1.3390 - val_loss: 32.7573 - val_y1_output_loss: 6.7337 - val_y2_output_loss: 25.6460 - val_y1_output_root_mean_squared_error: 2.6197 - val_y2_output_root_mean_squared_error: 5.0886
# Epoch 107/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.2045 - y1_output_loss: 0.8456 - y2_output_loss: 2.3382 - y1_output_root_mean_squared_error: 0.9233 - y2_output_root_mean_squared_error: 1.5337 - val_loss: 2.2025 - val_y1_output_loss: 0.5658 - val_y2_output_loss: 1.5942 - val_y1_output_root_mean_squared_error: 0.7645 - val_y2_output_root_mean_squared_error: 1.2720
# Epoch 108/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5352 - y1_output_loss: 0.5230 - y2_output_loss: 2.0362 - y1_output_root_mean_squared_error: 0.7240 - y2_output_root_mean_squared_error: 1.4181 - val_loss: 10.5993 - val_y1_output_loss: 1.6829 - val_y2_output_loss: 8.6318 - val_y1_output_root_mean_squared_error: 1.3158 - val_y2_output_root_mean_squared_error: 2.9779
# Epoch 109/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2291 - y1_output_loss: 0.5117 - y2_output_loss: 1.7186 - y1_output_root_mean_squared_error: 0.7166 - y2_output_root_mean_squared_error: 1.3098 - val_loss: 3.0718 - val_y1_output_loss: 0.5664 - val_y2_output_loss: 2.4417 - val_y1_output_root_mean_squared_error: 0.7661 - val_y2_output_root_mean_squared_error: 1.5764
# Epoch 110/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.1227 - y1_output_loss: 1.3542 - y2_output_loss: 3.7427 - y1_output_root_mean_squared_error: 1.1599 - y2_output_root_mean_squared_error: 1.9435 - val_loss: 2.2816 - val_y1_output_loss: 0.6321 - val_y2_output_loss: 1.5852 - val_y1_output_root_mean_squared_error: 0.8014 - val_y2_output_root_mean_squared_error: 1.2803
# Epoch 111/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8268 - y1_output_loss: 0.5707 - y2_output_loss: 2.2576 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.5023 - val_loss: 3.4736 - val_y1_output_loss: 0.9611 - val_y2_output_loss: 2.4842 - val_y1_output_root_mean_squared_error: 0.9897 - val_y2_output_root_mean_squared_error: 1.5793
# Epoch 112/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.2450 - y1_output_loss: 2.1055 - y2_output_loss: 5.0899 - y1_output_root_mean_squared_error: 1.4562 - y2_output_root_mean_squared_error: 2.2638 - val_loss: 2.8139 - val_y1_output_loss: 0.5309 - val_y2_output_loss: 2.1890 - val_y1_output_root_mean_squared_error: 0.7399 - val_y2_output_root_mean_squared_error: 1.5055
# Epoch 113/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6403 - y1_output_loss: 0.5575 - y2_output_loss: 2.0901 - y1_output_root_mean_squared_error: 0.7364 - y2_output_root_mean_squared_error: 1.4484 - val_loss: 2.4064 - val_y1_output_loss: 0.8438 - val_y2_output_loss: 1.4967 - val_y1_output_root_mean_squared_error: 0.9324 - val_y2_output_root_mean_squared_error: 1.2398
# Epoch 114/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0455 - y1_output_loss: 0.7652 - y2_output_loss: 2.3301 - y1_output_root_mean_squared_error: 0.8752 - y2_output_root_mean_squared_error: 1.5098 - val_loss: 10.7473 - val_y1_output_loss: 0.8045 - val_y2_output_loss: 9.6860 - val_y1_output_root_mean_squared_error: 0.9091 - val_y2_output_root_mean_squared_error: 3.1498
# Epoch 115/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.0225 - y1_output_loss: 0.9494 - y2_output_loss: 3.0351 - y1_output_root_mean_squared_error: 0.9789 - y2_output_root_mean_squared_error: 1.7505 - val_loss: 1.8994 - val_y1_output_loss: 0.4207 - val_y2_output_loss: 1.4217 - val_y1_output_root_mean_squared_error: 0.6599 - val_y2_output_root_mean_squared_error: 1.2099
# Epoch 116/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7020 - y1_output_loss: 0.6310 - y2_output_loss: 2.0548 - y1_output_root_mean_squared_error: 0.7966 - y2_output_root_mean_squared_error: 1.4379 - val_loss: 2.6889 - val_y1_output_loss: 0.5972 - val_y2_output_loss: 2.0089 - val_y1_output_root_mean_squared_error: 0.7850 - val_y2_output_root_mean_squared_error: 1.4397
# Epoch 117/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7059 - y1_output_loss: 0.5254 - y2_output_loss: 2.1875 - y1_output_root_mean_squared_error: 0.7219 - y2_output_root_mean_squared_error: 1.4781 - val_loss: 5.9093 - val_y1_output_loss: 1.6848 - val_y2_output_loss: 4.0665 - val_y1_output_root_mean_squared_error: 1.3100 - val_y2_output_root_mean_squared_error: 2.0477
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1403 - y1_output_loss: 0.4453 - y2_output_loss: 1.7048 - y1_output_root_mean_squared_error: 0.6650 - y2_output_root_mean_squared_error: 1.3031 - val_loss: 2.4828 - val_y1_output_loss: 0.6013 - val_y2_output_loss: 1.8304 - val_y1_output_root_mean_squared_error: 0.7881 - val_y2_output_root_mean_squared_error: 1.3645
# Epoch 119/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4944 - y1_output_loss: 0.5262 - y2_output_loss: 1.9696 - y1_output_root_mean_squared_error: 0.7248 - y2_output_root_mean_squared_error: 1.4032 - val_loss: 4.0725 - val_y1_output_loss: 1.1253 - val_y2_output_loss: 2.9003 - val_y1_output_root_mean_squared_error: 1.0721 - val_y2_output_root_mean_squared_error: 1.7097
# Epoch 120/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5578 - y1_output_loss: 0.5243 - y2_output_loss: 2.0169 - y1_output_root_mean_squared_error: 0.7254 - y2_output_root_mean_squared_error: 1.4254 - val_loss: 2.1722 - val_y1_output_loss: 0.4559 - val_y2_output_loss: 1.6423 - val_y1_output_root_mean_squared_error: 0.6841 - val_y2_output_root_mean_squared_error: 1.3055
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4662 - y1_output_loss: 0.1319 - y2_output_loss: 0.3302 - y1_output_root_mean_squared_error: 0.3647 - y2_output_root_mean_squared_error: 0.5772 - val_loss: 0.6666 - val_y1_output_loss: 0.1603 - val_y2_output_loss: 0.4917 - val_y1_output_root_mean_squared_error: 0.4024 - val_y2_output_root_mean_squared_error: 0.7104
# Epoch 462/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5109 - y1_output_loss: 0.1440 - y2_output_loss: 0.3653 - y1_output_root_mean_squared_error: 0.3788 - y2_output_root_mean_squared_error: 0.6062 - val_loss: 1.4632 - val_y1_output_loss: 0.3963 - val_y2_output_loss: 1.0324 - val_y1_output_root_mean_squared_error: 0.6295 - val_y2_output_root_mean_squared_error: 1.0329
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4070 - y1_output_loss: 0.1268 - y2_output_loss: 0.2805 - y1_output_root_mean_squared_error: 0.3546 - y2_output_root_mean_squared_error: 0.5303 - val_loss: 0.7794 - val_y1_output_loss: 0.2278 - val_y2_output_loss: 0.5439 - val_y1_output_root_mean_squared_error: 0.4773 - val_y2_output_root_mean_squared_error: 0.7427
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.7686 - y1_output_loss: 0.2166 - y2_output_loss: 0.5458 - y1_output_root_mean_squared_error: 0.4672 - y2_output_root_mean_squared_error: 0.7418 - val_loss: 0.7782 - val_y1_output_loss: 0.1627 - val_y2_output_loss: 0.5928 - val_y1_output_root_mean_squared_error: 0.4047 - val_y2_output_root_mean_squared_error: 0.7839
# Epoch 465/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5756 - y1_output_loss: 0.1528 - y2_output_loss: 0.4273 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.6518 - val_loss: 2.0801 - val_y1_output_loss: 0.5303 - val_y2_output_loss: 1.5018 - val_y1_output_root_mean_squared_error: 0.7285 - val_y2_output_root_mean_squared_error: 1.2447
# Epoch 466/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4648 - y1_output_loss: 0.1388 - y2_output_loss: 0.3220 - y1_output_root_mean_squared_error: 0.3741 - y2_output_root_mean_squared_error: 0.5699 - val_loss: 0.6255 - val_y1_output_loss: 0.1694 - val_y2_output_loss: 0.4403 - val_y1_output_root_mean_squared_error: 0.4120 - val_y2_output_root_mean_squared_error: 0.6751
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4079 - y1_output_loss: 0.1372 - y2_output_loss: 0.2803 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5216 - val_loss: 1.2150 - val_y1_output_loss: 0.4153 - val_y2_output_loss: 0.7982 - val_y1_output_root_mean_squared_error: 0.6336 - val_y2_output_root_mean_squared_error: 0.9020
# Epoch 468/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3646 - y1_output_loss: 0.1278 - y2_output_loss: 0.2373 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.4868 - val_loss: 0.6792 - val_y1_output_loss: 0.2059 - val_y2_output_loss: 0.4584 - val_y1_output_root_mean_squared_error: 0.4576 - val_y2_output_root_mean_squared_error: 0.6855
# Epoch 469/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3837 - y1_output_loss: 0.1335 - y2_output_loss: 0.2509 - y1_output_root_mean_squared_error: 0.3644 - y2_output_root_mean_squared_error: 0.5009 - val_loss: 0.9558 - val_y1_output_loss: 0.3511 - val_y2_output_loss: 0.5844 - val_y1_output_root_mean_squared_error: 0.5970 - val_y2_output_root_mean_squared_error: 0.7742
# Epoch 470/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4606 - y1_output_loss: 0.1669 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.4059 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 1.8282 - val_y1_output_loss: 0.3825 - val_y2_output_loss: 1.4018 - val_y1_output_root_mean_squared_error: 0.6233 - val_y2_output_root_mean_squared_error: 1.1999
# Epoch 471/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4672 - y1_output_loss: 0.1592 - y2_output_loss: 0.3091 - y1_output_root_mean_squared_error: 0.3974 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 2.1977 - val_y1_output_loss: 0.4923 - val_y2_output_loss: 1.6506 - val_y1_output_root_mean_squared_error: 0.7059 - val_y2_output_root_mean_squared_error: 1.3036
# Epoch 472/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4404 - y1_output_loss: 0.1502 - y2_output_loss: 0.2924 - y1_output_root_mean_squared_error: 0.3875 - y2_output_root_mean_squared_error: 0.5388 - val_loss: 0.9567 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.7594 - val_y1_output_root_mean_squared_error: 0.4331 - val_y2_output_root_mean_squared_error: 0.8770
# Epoch 473/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3955 - y1_output_loss: 0.1243 - y2_output_loss: 0.2686 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5201 - val_loss: 0.8490 - val_y1_output_loss: 0.1710 - val_y2_output_loss: 0.6505 - val_y1_output_root_mean_squared_error: 0.4172 - val_y2_output_root_mean_squared_error: 0.8216
# Epoch 474/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3079 - y1_output_loss: 0.1136 - y2_output_loss: 0.1924 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.4402 - val_loss: 0.6872 - val_y1_output_loss: 0.1542 - val_y2_output_loss: 0.5199 - val_y1_output_root_mean_squared_error: 0.3973 - val_y2_output_root_mean_squared_error: 0.7276
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4383 - y1_output_loss: 0.1410 - y2_output_loss: 0.3167 - y1_output_root_mean_squared_error: 0.3722 - y2_output_root_mean_squared_error: 0.5475 - val_loss: 1.7422 - val_y1_output_loss: 0.4832 - val_y2_output_loss: 1.2241 - val_y1_output_root_mean_squared_error: 0.6927 - val_y2_output_root_mean_squared_error: 1.1236
# Epoch 476/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4120 - y1_output_loss: 0.1236 - y2_output_loss: 0.2907 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 0.8616 - val_y1_output_loss: 0.2129 - val_y2_output_loss: 0.6443 - val_y1_output_root_mean_squared_error: 0.4668 - val_y2_output_root_mean_squared_error: 0.8023
# Epoch 477/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3975 - y1_output_loss: 0.1327 - y2_output_loss: 0.2634 - y1_output_root_mean_squared_error: 0.3642 - y2_output_root_mean_squared_error: 0.5146 - val_loss: 0.6605 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.4362 - val_y1_output_root_mean_squared_error: 0.4595 - val_y2_output_root_mean_squared_error: 0.6703
# Epoch 478/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3389 - y1_output_loss: 0.1181 - y2_output_loss: 0.2182 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.4693 - val_loss: 0.6421 - val_y1_output_loss: 0.1603 - val_y2_output_loss: 0.4703 - val_y1_output_root_mean_squared_error: 0.4027 - val_y2_output_root_mean_squared_error: 0.6928
# Epoch 479/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4876 - y1_output_loss: 0.1451 - y2_output_loss: 0.3435 - y1_output_root_mean_squared_error: 0.3805 - y2_output_root_mean_squared_error: 0.5855 - val_loss: 0.7274 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.5132 - val_y1_output_root_mean_squared_error: 0.4435 - val_y2_output_root_mean_squared_error: 0.7285
# Epoch 480/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3536 - y1_output_loss: 0.1240 - y2_output_loss: 0.2304 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 0.8985 - val_y1_output_loss: 0.1777 - val_y2_output_loss: 0.6992 - val_y1_output_root_mean_squared_error: 0.4259 - val_y2_output_root_mean_squared_error: 0.8468
# Epoch 481/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3052 - y1_output_loss: 0.1130 - y2_output_loss: 0.1949 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.4414 - val_loss: 1.3117 - val_y1_output_loss: 0.4206 - val_y2_output_loss: 0.8777 - val_y1_output_root_mean_squared_error: 0.6436 - val_y2_output_root_mean_squared_error: 0.9474
# Epoch 482/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3086 - y1_output_loss: 0.1211 - y2_output_loss: 0.1911 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.4337 - val_loss: 0.8148 - val_y1_output_loss: 0.1758 - val_y2_output_loss: 0.6136 - val_y1_output_root_mean_squared_error: 0.4233 - val_y2_output_root_mean_squared_error: 0.7972
# Epoch 483/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3399 - y1_output_loss: 0.1276 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.4601 - val_loss: 0.6755 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 0.4811 - val_y1_output_root_mean_squared_error: 0.4209 - val_y2_output_root_mean_squared_error: 0.7060
# Epoch 484/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4247 - y1_output_loss: 0.1363 - y2_output_loss: 0.2870 - y1_output_root_mean_squared_error: 0.3681 - y2_output_root_mean_squared_error: 0.5378 - val_loss: 0.6524 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.4445 - val_y1_output_root_mean_squared_error: 0.4424 - val_y2_output_root_mean_squared_error: 0.6758
# Epoch 485/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4058 - y1_output_loss: 0.1541 - y2_output_loss: 0.2566 - y1_output_root_mean_squared_error: 0.3903 - y2_output_root_mean_squared_error: 0.5035 - val_loss: 1.1089 - val_y1_output_loss: 0.2127 - val_y2_output_loss: 0.8690 - val_y1_output_root_mean_squared_error: 0.4616 - val_y2_output_root_mean_squared_error: 0.9465
# Epoch 486/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3777 - y1_output_loss: 0.1268 - y2_output_loss: 0.2495 - y1_output_root_mean_squared_error: 0.3565 - y2_output_root_mean_squared_error: 0.5006 - val_loss: 0.8812 - val_y1_output_loss: 0.2348 - val_y2_output_loss: 0.6316 - val_y1_output_root_mean_squared_error: 0.4852 - val_y2_output_root_mean_squared_error: 0.8036
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3601 - y1_output_loss: 0.1222 - y2_output_loss: 0.2363 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.4866 - val_loss: 0.7514 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 0.5762 - val_y1_output_root_mean_squared_error: 0.3964 - val_y2_output_root_mean_squared_error: 0.7709
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4589 - y1_output_loss: 0.1563 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3963 - y2_output_root_mean_squared_error: 0.5495 - val_loss: 0.7005 - val_y1_output_loss: 0.1458 - val_y2_output_loss: 0.5382 - val_y1_output_root_mean_squared_error: 0.3814 - val_y2_output_root_mean_squared_error: 0.7450
# Epoch 489/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3384 - y1_output_loss: 0.1243 - y2_output_loss: 0.2146 - y1_output_root_mean_squared_error: 0.3541 - y2_output_root_mean_squared_error: 0.4616 - val_loss: 0.7644 - val_y1_output_loss: 0.1888 - val_y2_output_loss: 0.5579 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.7579
# Epoch 490/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4206 - y1_output_loss: 0.1449 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3816 - y2_output_root_mean_squared_error: 0.5244 - val_loss: 0.6327 - val_y1_output_loss: 0.1862 - val_y2_output_loss: 0.4329 - val_y1_output_root_mean_squared_error: 0.4287 - val_y2_output_root_mean_squared_error: 0.6700
# Epoch 491/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3543 - y1_output_loss: 0.1163 - y2_output_loss: 0.2376 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4884 - val_loss: 0.7225 - val_y1_output_loss: 0.2248 - val_y2_output_loss: 0.4799 - val_y1_output_root_mean_squared_error: 0.4776 - val_y2_output_root_mean_squared_error: 0.7031
# Epoch 492/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2674 - y1_output_loss: 0.1076 - y2_output_loss: 0.1592 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.4002 - val_loss: 0.7999 - val_y1_output_loss: 0.2350 - val_y2_output_loss: 0.5471 - val_y1_output_root_mean_squared_error: 0.4851 - val_y2_output_root_mean_squared_error: 0.7514
# Epoch 493/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5316 - y1_output_loss: 0.1525 - y2_output_loss: 0.3747 - y1_output_root_mean_squared_error: 0.3919 - y2_output_root_mean_squared_error: 0.6149 - val_loss: 0.6443 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.4525 - val_y1_output_root_mean_squared_error: 0.4204 - val_y2_output_root_mean_squared_error: 0.6838
# Epoch 494/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4854 - y1_output_loss: 0.1388 - y2_output_loss: 0.3438 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5882 - val_loss: 0.7311 - val_y1_output_loss: 0.2121 - val_y2_output_loss: 0.5084 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.7230
# Epoch 495/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4674 - y1_output_loss: 0.1470 - y2_output_loss: 0.3174 - y1_output_root_mean_squared_error: 0.3850 - y2_output_root_mean_squared_error: 0.5650 - val_loss: 0.6109 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 0.4411 - val_y1_output_root_mean_squared_error: 0.4013 - val_y2_output_root_mean_squared_error: 0.6707
# Epoch 496/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4725 - y1_output_loss: 0.1420 - y2_output_loss: 0.3276 - y1_output_root_mean_squared_error: 0.3782 - y2_output_root_mean_squared_error: 0.5740 - val_loss: 0.9747 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 0.7777 - val_y1_output_root_mean_squared_error: 0.4167 - val_y2_output_root_mean_squared_error: 0.8950
# Epoch 497/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3455 - y1_output_loss: 0.1371 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.4677 - val_loss: 2.4464 - val_y1_output_loss: 0.8447 - val_y2_output_loss: 1.6181 - val_y1_output_root_mean_squared_error: 0.9143 - val_y2_output_root_mean_squared_error: 1.2690
# Epoch 498/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4580 - y1_output_loss: 0.1556 - y2_output_loss: 0.2998 - y1_output_root_mean_squared_error: 0.3961 - y2_output_root_mean_squared_error: 0.5487 - val_loss: 0.6653 - val_y1_output_loss: 0.1661 - val_y2_output_loss: 0.4887 - val_y1_output_root_mean_squared_error: 0.4099 - val_y2_output_root_mean_squared_error: 0.7052
# Epoch 499/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3629 - y1_output_loss: 0.1277 - y2_output_loss: 0.2329 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.4844 - val_loss: 0.6799 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 0.4554 - val_y1_output_root_mean_squared_error: 0.4630 - val_y2_output_root_mean_squared_error: 0.6823
# Epoch 500/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4054 - y1_output_loss: 0.1363 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.5192 - val_loss: 0.6298 - val_y1_output_loss: 0.1702 - val_y2_output_loss: 0.4462 - val_y1_output_root_mean_squared_error: 0.4161 - val_y2_output_root_mean_squared_error: 0.6758

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.6298 - y1_output_loss: 0.1707 - y2_output_loss: 0.4610 - y1_output_root_mean_squared_error: 0.4161 - y2_output_root_mean_squared_error: 0.6758
# Loss = 0.6298207168455248, Y1_loss = 0.170667827129364, Y1_mse = 0.41611990332603455, Y2_loss = 0.46099790930747986, Y2_mse = 0.6757698655128479

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
